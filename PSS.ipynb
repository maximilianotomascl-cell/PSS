# %% [markdown]
# <a href="https://colab.research.google.com/github/maximilianotomascl-cell/PSS/blob/main/PSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile holamundo.c
#
# #include <stdio.h>
#
# int main()
# {
#   printf("hola mundo\n");
# }
# Out:
# Writing holamundo.c
